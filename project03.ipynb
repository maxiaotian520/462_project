# %% [markdown]
# <a href="https://colab.research.google.com/github/maxiaotian520/462_project/blob/master/project03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
# import data
data = np.loadtxt('dataset1.csv',delimiter=',')
X = data[:201,:2]
y = data[:201,2]

# %% [markdown]
# **01. Use a Support Vector Machine with a linear kernel to fit and score a binary classifier for dataset 1.**

# %%
# fit and score
C = 1.0  # SVM regularization parameter
svc = svm.SVC(kernel='linear', C=C).fit(X, y)
print(svc.score(X, y))
# Out:
# 1.0

# %% [markdown]
# **02. Use your code from Project 2 to plot the decision boundary for experiment (1). Since SVMs are non-probabilistic classifiers you will need to use predict instead of predict_proba.**

# %%
# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
# Put the result into a color plot
plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)
title = 'SVC with linear kernel'
# # Plot 
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.xlabel('x1')
plt.ylabel('x2')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())
plt.title(title)
plt.show()

# %% [markdown]
# **03. Repeat experiments (1) and (2) with the 'poly', 'rbf', and 'sigmoid' kernels. Do they produce different decision boundaries?**

# %%
rbf_svc = svm.SVC(kernel='rbf', C=C).fit(X, y)
poly_svc = svm.SVC(kernel='poly', C=C).fit(X, y)
sigmoid_svc = svm.SVC(kernel='sigmoid', gamma=2, C=C).fit(X, y)

# %%
# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %%
# title for the plots
titles = ['SVC with sigmoid kernel',
          'SVC with RBF kernel',
          'SVC with polynomial kernel']

# %%
# see reference  https://scikit-learn.org/0.18/auto_examples/svm/plot_iris.html
for i, clf in enumerate((sigmoid_svc, rbf_svc, poly_svc)):
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)
    
    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(titles[i])
    plt.show()

# %% [markdown]
# Answer: They produce different decision boundaries.
#
# ---

# %% [markdown]
# **04. Repeat experiments (1) through (3) with dataset 2. Which kernel produces the best decision boundary?**

# %%
#Repeat experiment 01
data = np.loadtxt('dataset2.csv',delimiter=',')
X02 = data[:201,:2]
y02 = data[:201,2]

# %%
# fit and score
C = 1.0  # SVM regularization parameter
svc02 = svm.SVC(kernel='linear', C=C).fit(X02, y02)
print(svc02.score(X02, y02))
# Out:
# 0.62

# %%
# repeat experiment 02
h = .02  # step size in the mesh
x_min, x_max = X02[:, 0].min() - 1, X02[:, 0].max() + 1
y_min, y_max = X02[:, 1].min() - 1, X02[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z02 = svc02.predict(np.c_[xx.ravel(), yy.ravel()])
Z02 = Z02.reshape(xx.shape)

# Put the result into a color plot
plt.contourf(xx, yy, Z02, cmap=plt.cm.coolwarm, alpha=0.8)
title02 = 'SVC with sigmoid kernel'
# # Plot 
plt.scatter(X02[:, 0], X02[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.xlabel('x1')
plt.ylabel('x2')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())
plt.title(title02)
plt.show()

# %%
#repeat experiment 03
rbf_svc02 = svm.SVC(kernel='rbf', C=C).fit(X02, y02)
poly_svc02 = svm.SVC(kernel='poly', C=C).fit(X02, y02)
sigmoid_svc02 = svm.SVC(kernel='sigmoid', gamma=2, C=C).fit(X02, y02)

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X02[:, 0].min() - 1, X02[:, 0].max() + 1
y_min, y_max = X02[:, 1].min() - 1, X02[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# title for the plots
titles = ['SVC with sigmoid kernel',
          'SVC with RBF kernel',
          'SVC with polynomial kernel']

for i, clf in enumerate((sigmoid_svc02, rbf_svc02, poly_svc02)):
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)
    
    # Plot also the training points
    plt.scatter(X02[:, 0], X02[:, 1], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(titles[i])
    plt.show()

# %% [markdown]
# **05. Try changing the degree for the 'poly' kernel from the default degree 3 to degree 5. Plot the decision boundary and create a confusion matrix for both models. What differences do you observe between the two?**

# %%
#Repeat experiment 01
data = np.loadtxt('dataset2.csv',delimiter=',')
X02 = data[:201,:2]
y02 = data[:201,2]

# %%
#poly_svc03 = svm.SVC(kernel='poly', degree=5, C=C).fit(X02, y02)
poly_svc03 = svm.SVC(kernel='poly', degree=5, C=C).fit(X02, y02)

h = .02  # step size in the mesh
x_min, x_max = X02[:, 0].min() - 1, X02[:, 0].max() + 1
y_min, y_max = X02[:, 1].min() - 1, X02[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z03 = poly_svc03.predict(np.c_[xx.ravel(), yy.ravel()])
Z03 = Z03.reshape(xx.shape)

# Put the result into a color plot
plt.contourf(xx, yy, Z03, cmap=plt.cm.coolwarm, alpha=0.8)
title02 = 'SVC with polynomial kernel'
# # Plot 
plt.scatter(X02[:, 0], X02[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.xlabel('x1')
plt.ylabel('x2')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())
plt.title(title02)
plt.show()

# %%
#create a confusion matrix for model with degree 5
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix

disp = plot_confusion_matrix(poly_svc03, X02, y02)
disp.ax_.set_title('Confusion matrix with degree 5')

#print(title)
print(disp.confusion_matrix)

plt.show()
# Out:
# [[77 23]
#  [ 1 99]]

# %%
#create a confusion matrix for model with degree 3
from sklearn.metrics import confusion_matrix
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
disp = plot_confusion_matrix(poly_svc, X02, y02)
disp.ax_.set_title('Confusion matrix with degree 3')

#print(title)
print(disp.confusion_matrix)

plt.show()
# Out:
# [[50 50]
#  [52 48]]

# %% [markdown]
# **06. Repeat experiments (1) through (3) for dataset 3. Which kernel produces the best decision boundary? Does it seem as if the 'poly' kernel should have scored higher?**

# %%
#Repeat experiment 1
data = np.loadtxt('dataset3.csv',delimiter=',')
X04 = data[:201,:2]
y04 = data[:201,2]

# %%
# fit and score
C = 1.0  # SVM regularization parameter
svc04 = svm.SVC(kernel='linear', C=C).fit(X04, y04)
print(svc04.score(X04, y04))
# Out:
# 0.88

# %%
#Repeat experiment 2
# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X04[:, 0].min() - 1, X04[:, 0].max() + 1
y_min, y_max = X04[:, 1].min() - 1, X04[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z04 = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z04 = Z04.reshape(xx.shape)

# %%
# Put the result into a color plot
plt.contourf(xx, yy, Z04, cmap=plt.cm.coolwarm, alpha=0.8)
title = 'SVC with linear kernel'
# # Plot 
plt.scatter(X04[:, 0], X04[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.xlabel('x1')
plt.ylabel('x2')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())
plt.title(title)
plt.show()

# %%
#Repeat experiment 3
rbf_svc04 = svm.SVC(kernel='rbf', C=C).fit(X04, y04)
poly_svc04 = svm.SVC(kernel='poly', C=C).fit(X04, y04)
sigmoid_svc04 = svm.SVC(kernel='sigmoid', gamma=2, C=C).fit(X04, y04)

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X04[:, 0].min() - 1, X04[:, 0].max() + 1
y_min, y_max = X04[:, 1].min() - 1, X04[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# title for the plots
titles = ['SVC with sigmoid kernel',
          'SVC with RBF kernel',
          'SVC with polynomial kernel']

for i, clf in enumerate((sigmoid_svc, rbf_svc, poly_svc)):
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].

    Z04 = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    # Put the result into a color plot
    Z04 = Z04.reshape(xx.shape)
    plt.contourf(xx, yy, Z04, cmap=plt.cm.coolwarm, alpha=0.8)
    
    # Plot also the training points
    plt.scatter(X04[:, 0], X04[:, 1], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(titles[i])
    plt.show()

# %%
# Compare scores of different kernel
print("Linear_score:", svc04.score(X04, y04))
print("rbf_score:", rbf_svc04.score(X04, y04))
print("poly_score:", poly_svc04.score(X04, y04))
print("sigmoid_score:", sigmoid_svc04.score(X04, y04))
# Out:
# Linear_score: 0.88
# rbf_score: 1.0
# poly_score: 0.915
# sigmoid_score: 0.5

# %% [markdown]
# Answer: Obviously, the score of poly kernel is higer than other scores of kernel.

# %% [markdown]
# **07. Use grid search with cross-validation to determine which combination of hyperparameters produces the best fit for the 'poly' kernel on dataset 3. Try the following:
# Regularization parameter C values of 0.001, 0.01, 0.1, and 1.0
# Polynomial degrees 3, 5, and 7
# Independent coef0 terms 0.01, 0.1, and 1.0
# Which values turn out to be the best_params_? Plot the decision boundary and create a confusion matrix to verify this.**

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

# %%
data = np.loadtxt('dataset3.csv',delimiter=',')
X_train = data[:100,:2]
y_train = data[:100,2][:,None]
X_test = data[100:201,:2]
y_test = data[100:201,2][:,None]

X05 = data[:201,:2]
y05 = data[:201,2]

# %%
# Set the parameters by cross-validation
tuned_parameters = [{'C': [0.001, 0.01, 0.1, 1.0], 'coef0': [ 0.01, 0.1, 1.0], 'degree': [3, 5, 7], 'gamma': [1e-3, 1e-4],
                      'kernel': ['poly']}]

#print("# Tuning hyper-parameters for %s" % score)
score = 'precision'
clf = GridSearchCV(SVC(), tuned_parameters, scoring='%s_macro' % score)
clf.fit(X_train, y_train)
print()
print("Best parameters set found on development set:")
print(clf.best_params_)
print()
print("Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
  print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
#Plot the decision boundary and create a confusion matrix to verify this.
#{'C': 1.0, 'coef0': 1.0, 'degree': 7, 'gamma': 0.001, 'kernel': 'poly'}
poly_svc05 = svm.SVC(kernel='poly', degree=7, coef0=1.0).fit(X05, y05)

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X05[:, 0].min() - 1, X05[:, 0].max() + 1
y_min, y_max = X05[:, 1].min() - 1, X05[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

Z05 = poly_svc05.predict(np.c_[xx.ravel(), yy.ravel()])
Z05 = Z05.reshape(xx.shape)

# Put the result into a color plot
plt.contourf(xx, yy, Z05, cmap=plt.cm.coolwarm, alpha=0.8)
title = 'SVC with linear kernel'
# # Plot 
plt.scatter(X05[:, 0], X05[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.xlabel('x1')
plt.ylabel('x2')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())
plt.title(title)
plt.show()

# %%
#create a confusion matrix for model with degree 5
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
disp = plot_confusion_matrix(poly_svc05, X05, y05)
disp.ax_.set_title('Confusion matrix with degree 7')

#print(title)
print(disp.confusion_matrix)

plt.show()
# Out:
# [[100   0]
#  [  0 100]]
